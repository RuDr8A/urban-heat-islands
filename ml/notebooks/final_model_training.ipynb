# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from xgboost import XGBRegressor

import joblib
import json
import os

# %%
data_path = (
    "../../data/processed/"
    "raipur_5year_processed.csv"
)

df = pd.read_csv(data_path)

print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset shape: (12500, 16)
#    longitude   latitude  Year        LST      NDVI      NDBI      NDWI  \
# 0  81.633354  21.118583  2022  47.385043  0.144367  0.070714 -0.191317
# 1  81.633354  21.118583  2023  48.783013  0.090909  0.025947 -0.122160
# 2  81.633354  21.118583  2024  56.919609  0.113913  0.072583 -0.159775
# 3  81.633354  21.118583  2025  39.979902  0.112862  0.072756 -0.155619
# 4  81.633354  21.118583  2026  49.784493  0.098629  0.083194 -0.139808
#
#            location_id  LST_change  NDVI_change  NDBI_change  NDWI_change  \
# 0  21.118583_81.633354         NaN          NaN          NaN          NaN
# 1  21.118583_81.633354    1.397970    -0.053457    -0.044768     0.069158
# 2  21.118583_81.633354    8.136597     0.023004     0.046637    -0.037615
# 3  21.118583_81.633354  -16.939707    -0.001051     0.000173     0.004157
# 4  21.118583_81.633354    9.804590    -0.014233     0.010438     0.015811
#
#    LST_from_2022  NDVI_from_2022  NDBI_from_2022  NDWI_from_2022
# ...

# %%
print(
    df["Year"]
    .value_counts()
    .sort_index()
)
# Out:
# Year
# 2022    2500
# 2023    2500
# 2024    2500
# 2025    2500
# 2026    2500
# Name: count, dtype: int64

# %%
train_df = df[
    df["Year"] < 2026
].copy()

test_df = df[
    df["Year"] == 2026
].copy()

print(
    "Training samples:",
    len(train_df)
)

print(
    "Testing samples:",
    len(test_df)
)
# Out:
# Training samples: 10000
# Testing samples: 2500

# %%
environmental_features = [
    "NDVI",
    "NDBI",
    "NDWI"
]

spatial_features = [
    "NDVI",
    "NDBI",
    "NDWI",
    "latitude",
    "longitude"
]

full_features = [
    "NDVI",
    "NDBI",
    "NDWI",
    "latitude",
    "longitude",
    "Year"
]

target = "LST"

# %%
X_train_env = train_df[
    environmental_features
]

X_test_env = test_df[
    environmental_features
]

X_train_spatial = train_df[
    spatial_features
]

X_test_spatial = test_df[
    spatial_features
]

X_train_full = train_df[
    full_features
]

X_test_full = test_df[
    full_features
]

y_train = train_df[target]
y_test = test_df[target]

# %%
def evaluate_model(name, y_true, predictions):

    mae = mean_absolute_error(
        y_true,
        predictions
    )

    rmse = np.sqrt(
        mean_squared_error(
            y_true,
            predictions
        )
    )

    r2 = r2_score(
        y_true,
        predictions
    )

    print(f"\n{name}")
    print("-" * len(name))
    print(f"MAE  : {mae:.4f} °C")
    print(f"RMSE : {rmse:.4f} °C")
    print(f"R²   : {r2:.4f}")

    return {
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }

# %%
rf_env = RandomForestRegressor(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

rf_env.fit(
    X_train_env,
    y_train
)
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
rf_env_pred = rf_env.predict(
    X_test_env
)

# %%
rf_env_results = evaluate_model(
    "Random Forest - Environmental",
    y_test,
    rf_env_pred
)
# Out:
# Random Forest - Environmental
# -----------------------------
# MAE  : 2.1803 °C
# RMSE : 2.6905 °C
# R²   : 0.2214

# %%
xgb_env = XGBRegressor(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42
)

xgb_env.fit(
    X_train_env,
    y_train
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_env_pred = xgb_env.predict(
    X_test_env
)

# %%
xgb_env_results = evaluate_model(
    "XGBoost - Environmental",
    y_test,
    xgb_env_pred
)
# Out:
# XGBoost - Environmental
# -----------------------
# MAE  : 1.9837 °C
# RMSE : 2.4461 °C
# R²   : 0.3564

# %%
rf_spatial = RandomForestRegressor(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

rf_spatial.fit(
    X_train_spatial,
    y_train
)

rf_spatial_pred = rf_spatial.predict(
    X_test_spatial
)

# %%
rf_spatial_results = evaluate_model(
    "Random Forest - Environmental + Spatial",
    y_test,
    rf_spatial_pred
)
# Out:
# Random Forest - Environmental + Spatial
# ---------------------------------------
# MAE  : 2.2055 °C
# RMSE : 2.6739 °C
# R²   : 0.2310

# %%
rf_full = RandomForestRegressor(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

rf_full.fit(
    X_train_full,
    y_train
)

rf_full_pred = rf_full.predict(
    X_test_full
)

# %%
rf_full = RandomForestRegressor(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

rf_full.fit(
    X_train_full,
    y_train
)

rf_full_pred = rf_full.predict(
    X_test_full
)

# %%
rf_full_results = evaluate_model(
    "Random Forest - Full",
    y_test,
    rf_full_pred
)
# Out:
# Random Forest - Full
# --------------------
# MAE  : 5.0786 °C
# RMSE : 5.7588 °C
# R²   : -2.5669

# %%
results = pd.DataFrame([
    rf_env_results,
    xgb_env_results,
    rf_spatial_results,
    rf_full_results
])

results
# Out:
#                                      Model       MAE      RMSE        R2
# 0            Random Forest - Environmental  2.180277  2.690495  0.221442
# 1                  XGBoost - Environmental  1.983683  2.446149  0.356435
# 2  Random Forest - Environmental + Spatial  2.205528  2.673914  0.231009
# 3                     Random Forest - Full  5.078567  5.758804 -2.566900

# %%
final_model = xgb_env

final_features = environmental_features

final_predictions = xgb_env_pred

print("Final model: XGBoost Regressor")
print("Features:", final_features)
# Out:
# Final model: XGBoost Regressor
# Features: ['NDVI', 'NDBI', 'NDWI']

# %%
final_mae = mean_absolute_error(
    y_test,
    final_predictions
)

final_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        final_predictions
    )
)

final_r2 = r2_score(
    y_test,
    final_predictions
)

print("FINAL MODEL")
print("===========")

print(
    f"MAE  : {final_mae:.4f} °C"
)

print(
    f"RMSE : {final_rmse:.4f} °C"
)

print(
    f"R²   : {final_r2:.4f}"
)
# Out:
# FINAL MODEL
# ...
# MAE  : 1.9837 °C
# RMSE : 2.4461 °C
# R²   : 0.3564

# %%
plt.figure(figsize=(8, 8))

plt.scatter(
    y_test,
    final_predictions,
    alpha=0.5
)

min_value = min(
    y_test.min(),
    final_predictions.min()
)

max_value = max(
    y_test.max(),
    final_predictions.max()
)

plt.plot(
    [min_value, max_value],
    [min_value, max_value],
    linestyle="--"
)

plt.xlabel(
    "Observed LST (°C)"
)

plt.ylabel(
    "Predicted LST (°C)"
)

plt.title(
    "Observed vs Predicted LST — 2026"
)

plt.grid(True)

plt.show()

# %%
residuals = (
    y_test - final_predictions
)

# %%
plt.figure(figsize=(9, 5))

plt.scatter(
    final_predictions,
    residuals,
    alpha=0.5
)

plt.axhline(
    y=0,
    linestyle="--"
)

plt.xlabel(
    "Predicted LST (°C)"
)

plt.ylabel(
    "Residual (°C)"
)

plt.title(
    "Prediction Residuals — 2026"
)

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(9, 5))

plt.hist(
    residuals,
    bins=30
)

plt.xlabel(
    "Prediction Error (°C)"
)

plt.ylabel(
    "Number of Locations"
)

plt.title(
    "Distribution of LST Prediction Errors"
)

plt.grid(True)

plt.show()

# %%
importance = pd.DataFrame({
    "Feature": final_features,
    "Importance": final_model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#   Feature  Importance
# 1    NDBI    0.533293
# 0    NDVI    0.269820
# 2    NDWI    0.196887

# %%
plt.figure(figsize=(8, 5))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.xlabel(
    "Importance"
)

plt.ylabel(
    "Feature"
)

plt.title(
    "XGBoost Feature Importance"
)

plt.gca().invert_yaxis()

plt.grid(axis="x")

plt.show()

# %%
os.makedirs(
    "../models",
    exist_ok=True
)

# %%
model_path = (
    "../models/"
    "final_first_xgboost_environmental.pkl"
)

joblib.dump(
    final_model,
    model_path
)

print(
    f"Model saved to: {model_path}"
)
# Out:
# Model saved to: ../models/final_first_xgboost_environmental.pkl

# %%
metadata = {
    "model_type": "XGBoost Regressor",
    "features": final_features,
    "target": "LST",
    "training_years": [
        2022,
        2023,
        2024,
        2025
    ],
    "test_year": 2026,
    "mae": float(final_mae),
    "rmse": float(final_rmse),
    "r2": float(final_r2)
}

metadata_path = (
    "../models/"
    "final_first_xgboost_environmental_metadata.json"
)

with open(
    metadata_path,
    "w"
) as f:

    json.dump(
        metadata,
        f,
        indent=4
    )

print(
    f"Metadata saved to: {metadata_path}"
)
# Out:
# Metadata saved to: ../models/final_first_xgboost_environmental_metadata.json

# %%
prediction_map = test_df[
    [
        "longitude",
        "latitude",
        "Year",
        "LST",
        "NDVI",
        "NDBI",
        "NDWI"
    ]
].copy()

prediction_map = prediction_map.rename(
    columns={
        "LST": "observed_LST"
    }
)

prediction_map[
    "predicted_LST"
] = final_predictions

prediction_map[
    "prediction_error"
] = (
    prediction_map["observed_LST"]
    - prediction_map["predicted_LST"]
)

# %%
prediction_map.head()
# Out:
#     longitude   latitude  Year  observed_LST      NDVI      NDBI      NDWI  \
# 4   81.633354  21.118583  2026     49.784493  0.098629  0.083194 -0.139808
# 9   81.621632  21.118771  2026     52.371934  0.096673  0.076885 -0.142427
# 14  81.621544  21.119428  2026     52.474474  0.093956  0.079217 -0.138296
# 19  81.628593  21.119945  2026     51.478122  0.120403  0.069468 -0.173738
# 24  81.625616  21.120315  2026     53.139279  0.097107  0.080233 -0.139321
#
#     predicted_LST  prediction_error
# 4       50.603085         -0.818592
# 9       48.945923          3.426011
# 14      49.379753          3.094721
# 19      47.358128          4.119994
# 24      49.366962          3.772317

# %%
prediction_path = (
    "../../data/processed/"
    "raipur_2026_predictions.csv"
)

prediction_map.to_csv(
    prediction_path,
    index=False
)

print(
    f"Saved predictions to: {prediction_path}"
)
# Out:
# Saved predictions to: ../../data/processed/raipur_2026_predictions.csv
